# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %%
PATH_TO_FILTERED_VDJDB = "vdjdb.txt"

# %%
df = pd.read_table(PATH_TO_FILTERED_VDJDB)

# %%
df.head()
print(len(df))
# Out:
# 13320

# %%
unique_eps = df['antigen.epitope'].unique()
print(unique_eps)
# Out:
# ['NLVPMVATV' 'GILGFVFTL' 'QASQEVKNW' 'LPPIVAKEI' 'HPKVSSEVHI' 'TPRVTGGGAM'
#  'GTSGSPIVNR' 'VTEHDTLLY' 'GLCTLVAML' 'LLWNGPMAV' 'YVLDHLIVV' 'KAFSPEVIPMF'
#  'AMFWSVPTV' 'GTSGSPIINR' 'GPGHKARVL' 'IPSINVHHY' 'LLLGIGILV' 'EPLPQGQLTAY'
#  'ELAGIGILTV' 'KRWIILGLNK' 'LPRRSGAAGA' 'FRDYVDRFYKTLRAEQASQE' 'CINGVCWTV'
#  'ISPRTLNAW' 'RAKFKQLL' 'FLKEKGGL' 'RPRGEVRFL' 'PKYVKQNTLKLAT' 'FLYNLLTRV'
#  'NLSALGIFST' 'IVTDFSVIK' 'ATDALMTGY' 'KLVALGINAV' 'TPGPGVRYPL'
#  'KRWIIMGLNK' 'TPQDLNTML' 'FPRPWLHGL' 'GTSGSPIIDK' 'EIYKRWII' 'IIKDYGKQM'
#  'ARMILMTHF' 'QVPLRPMTYK' 'HSKKKCDEL' 'SLYNTVATL']

# %%
from Bio import pairwise2
from Bio.pairwise2 import format_alignment
from Bio.SubsMat import MatrixInfo as matlist
from math import exp

D_ep = np.ndarray(shape=(len(unique_eps), len(unique_eps)))
matrix = matlist.blosum62

for i in range(len(unique_eps)):
    for j in range(len(unique_eps)):
        #print(pairwise2.align.globaldx(unique_eps[i], unique_eps[j], matrix))
        D_ep[i, j] = pairwise2.align.globaldx(unique_eps[i], unique_eps[j], matrix)[0][2]

print(np.max(D_ep))
D_ep = D_ep / np.max(D_ep)  
        
plt.imshow(D_ep)
# Out:
# 103.0

# %%
PATH_TO_DIST = "pairwise_distances.txt/data"
dist = pd.read_table(PATH_TO_DIST)    
print(dist.head())

print(len(dist))
# Out:
#        species gene               to            from  indels  substs  \
# 0  HomoSapiens  TRA  CAAAATPGNTGKLIF  CAAFDSGNTGKLIF       1       3
# 1  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAFPGNTDKLIF       2       2
# 2  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAPGENTGKLIF       2       2
# 3  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAPPRNTGKLIF       2       2
# 4  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAPPSNTGKLIF       2       2
#
#          ag1        ag2
# 0  NLVPMVATV  GILGFVFTL
# 1  GILGFVFTL  GILGFVFTL
# 2  GILGFVFTL  GILGFVFTL
# 3  GILGFVFTL  GILGFVFTL
# 4  GILGFVFTL  GILGFVFTL
# 4594734

# %%
import networkx as nx
from nxpd import nxpdParams, draw
nxpdParams['show'] = 'ipynb'

import operator

    
    
#     G = nx.DiGraph()
#     G.graph['rankdir'] = 'LR'
#     G.graph['dpi'] = 120
#     print()
#     for i in d['to'].unique():
#         G.add_node(i, shape='square')
#     G.add_edge(d['to'].unique()[0], d['to'].unique()[1])
#     draw(G)

#     G = nx.DiGraph()
#     G.graph['rankdir'] = 'LR'
#     G.graph['dpi'] = 120
#     G.add_cycle(range(4))
#     G.add_node(0, color='red', style='filled', fillcolor='pink')
#     G.add_node(1, shape='square')
#     G.add_node(3, style='filled', fillcolor='#00ffff')
#     G.add_edge(0, 1, color='red', style='dashed')
#     G.add_edge(3, 3, label='a')
#     draw(G, show='ipynb')
    
grouped = df.groupby('antigen.epitope')
for it in grouped:
    #print(Counter(list(it[1]['antigen.species'])))
    if list(dict(Counter(list(it[1]['antigen.species']))).keys())[0] == 'InfluenzaA':
        process_epitope(it[1])
        df = it[1]
        cdrs = set(df['cdr3'])
        d = dist.loc[(dist['to'].isin(cdrs)) & dist['from'].isin(cdrs)]
        print("N paires is pairwise_distances.txt: {}".format(len(d)))

        tmp = ["subs_" + str(row[0]) + "_ind_" + str(row[1]) for index, row in d[['substs', 'indels']].iterrows()]
        print(sorted(dict(Counter(tmp)).items(), key=operator.itemgetter(1), reverse=True))

#         d_unique = d['to'].unique()
#         M = np.zeros((len(d_unique), len(d_unique)))
#         M_labels = {}
#         for i in range(len(d_unique)):
#             M_labels[d_unique[i]] = i

#         for index, row in d[['substs', 'indels']].iterrows():
#             if row[0] <= 3 & row[1] <= 1:
#                 M[M_labels[d['to'][index]], M_labels[d['from'][index]]] = 1
#                 M[M_labels[d['from'][index]], M_labels[d['to'][index]]] = 1

#         print(sum(sum(M)))

        G = nx.DiGraph()
        G.graph['rankdir'] = 'LR'
        G.graph['dpi'] = 120
        G.add_cycle(range(4))
        G.add_node(0, color='red', style='filled', fillcolor='pink')
        G.add_node(1, shape='square')
        G.add_node(3, style='filled', fillcolor='#00ffff')
        G.add_edge(0, 1, color='red', style='dashed')
        G.add_edge(3, 3, label='a')
        draw(G, show='ipynb')
# Out:
# N paires is pairwise_distances.txt: 1736
# [('subs_3_ind_2', 752), ('subs_3_ind_1', 426), ('subs_2_ind_2', 238), ('subs_2_ind_1', 128), ('subs_3_ind_0', 106), ('subs_1_ind_2', 28), ('subs_2_ind_0', 26), ('subs_1_ind_0', 16), ('subs_1_ind_1', 12), ('subs_0_ind_2', 4)]
# 8.0
#
# ===========
#
# N paires is pairwise_distances.txt: 1736
# [('subs_3_ind_2', 752), ('subs_3_ind_1', 426), ('subs_2_ind_2', 238), ('subs_2_ind_1', 128), ('subs_3_ind_0', 106), ('subs_1_ind_2', 28), ('subs_2_ind_0', 26), ('subs_1_ind_0', 16), ('subs_1_ind_1', 12), ('subs_0_ind_2', 4)]

# %%
G = nx.DiGraph()
G.graph['rankdir'] = 'LR'
G.graph['dpi'] = 120
G.add_cycle(range(4))
G.add_node(0, color='red', style='filled', fillcolor='pink')
G.add_node(1, shape='square')
G.add_node(3, style='filled', fillcolor='#00ffff')
G.add_edge(0, 1, color='red', style='dashed')
G.add_edge(3, 3, label='a')
draw(G)

# %%
mult = [(k, v) for k, v in dict(Counter(df['cdr3'])).items() if v > 1]
print(mult)
2), ('CASSLTSIAEAFF', 2), ('CASSLGGSENEKLFF', 2), ('CASSFDAGGNEQYF', 2), ('CASSLSPEYEQYF', 2), ('CASSGGRGNIQYF', 2), ('CASSTGTGQPQHF', 2), ('CASSDGTEQPQHF', 2), ('CASSSLNTEAFF', 2), ('CASSLGQGTYEQYF', 2), ('CASSFLPSGGPDYNEQFF', 2), ('CASSSRDSYEQYF', 2), ('CASRRPREGLANEQFF', 2), ('CASRKGQGDWEAFF', 2), ('CASSLGGA ...

# %%
len(Counter(df['cdr3']))
# Out:
# 13107

# %%
len(Counter(df['antigen.epitope']))
# Out:
# 44

# %%
# 1) gap penalty = -(max(vdjam) + 1)
# 2) score1 = global alignment score - gap penalty * #indels
# 3) score2(i,j) = score1(i, j) - max (score1(i,i), score2(j,j)) где i и j это два CDR3

# %%
PATH_TO_VDJAM = "./alignment_matrix/vdjam.txt"

# %%
m = pd.read_table(PATH_TO_VDJAM)
m.head()
# Out:
#   aa.1 aa.2     score
# 0    A    A  1.794124
# 1    A    C  0.982439
# 2    A    D -0.994039
# 3    A    E -0.977372
# 4    A    F -1.659467

# %%
vdjam = {}

for index, row in m.iterrows():
    vdjam[(row['aa.1'], row['aa.2'])] = row['score']
    
gap_penalty = -(max(vdjam.values()) + 1)

print(gap_penalty)
# Out:
# -7.72486062035267

# %%
from Bio import pairwise2
from Bio.pairwise2 import format_alignment


for a in pairwise2.align.globalds("KEVLA", "EVL", vdjam, gap_penalty, gap_penalty):
    print(format_alignment(*a))
# Out:
# KEVLA
# |||||
# -EVL-
#   Score=-7.30154

# %%
import itertools
from joblib import Parallel, delayed

cdr3 = df.head(100)['cdr3']

def f(pair):
    return pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)

results = Parallel(n_jobs=2, verbose=1, backend="threading")(map(delayed(f), itertools.combinations(cdr3, 2)))
print(results)
# Out:
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 796 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=2)]: Done 1246 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=2)]: Done 1796 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=2)]: Done 2446 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 3196 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=2)]: Done 4046 tasks      | elapsed:    2.6s
# [[('CASSF--SG--TQYF', 'CASSLGTSGGNEQFF', -9.185819048736096, 0, 15)], [('CASS----FSGTQYF', 'CASSQVEEFHGELFF', -10.63893301271855, 0, 15)], [('CAS-SF-SGTQYF', 'CASRTQRWETQYF', 3.68489076731408, 0, 13)], [('CASSF------SGTQYF', 'CASSPRQGLEGANVLTF', -30.745864692841266, 0, 17)], [('CAS-SFSGT---QYF', 'CSARDVAGGSLKQYF', -13.95061177293281, 0, 15)], [('CAS-SFSGTQY-F', 'CSARGGTSIFYTF', -4.561812604881506, 0, 13)], [('CASS-F--SGT---QYF', 'CASSSHERQGQNSPLHF', -30.155675830295152, 0, 17), ('CAS-SF--SGT---QYF', 'CASSSHERQGQNSPLHF', -30.155675830295152, 0, 17), ('CA-SSF--SGT---QYF', 'CASSSHERQGQNSPLHF', -30.155675830295152, 0, 17)], [('CASSFS--GT---QYF', 'CASSLIGEGTGWHQYF', -16.653795119882645, 0, 16), ('CASSFSG--T---QYF', 'CASSLIGEGTGWHQYF', -16.653795119882645, 
ASSYEQYF', -8.711792458615804, 0, 15)], [('CASSFSG-----TQYF', 'CASSLVGEGLRDEQFF', -18.851443130624048, 0, 16), ('CASSFSGT-----QYF', 'CASSLVGEGLRDEQFF', -18.851443130624048, 0, 16)], [('CASSF--SGTQYF', 'CASSIRGSYEQYF', 7.2813412786072895, 0, 13)], [('CASSFSGTQY-F', 'CSVGGTFYGYTF', 1.126829163942897, 0, 12)], [('CASSFSG----TQ----YF', 'CASSPTGLVGLIQNTEAFF', -43.012411719166955, 0, 19)], [('CASSFSGTQYF', 'CASSSVNEQFF', 16.20794682203199, 0, 11)], [('CASSFSG---TQYF', 'CASGGTGPWNEQFF', -6.065362347132467, 0, 14)], [('CASSFS----GTQYF', 'CASCIAPGVQETQYF', -7.879316753569718, 0, 15)], [('CASSF-SGTQ-YF', 'CASSIRANTEAFF', 3.113603419592421, 0, 13)], [('CASS--FSG-----TQYF', 'CASSQAYSGGLGTDTQYF', -28.931185936878414, 0, 18)], [('CASSFSGTQ--YF', 'CASSLGGTTEAFF', 4.943550305365504, 0, 13)], [('CASSFSGT----QYF', 'CASSLAGGAAEKLFF', -10.91001821724403, 0, 15)], [('CASSF--SG-T--QYF', 'CASSKRTSGATDEQFF', -17.058116480330234, 0, 16)], [('CASSF-SG--TQYF', 'CASSQDGGTYTQYF', -0.9229319517704409, 0, 14), ('CASSF-SGT--QYF', 'CASSQDGGTYTQYF', -0.9229319517704409, 0, 14)], [('CASSF---SG-----TQYF', 'CASSLSLTS ...
# [Parallel(n_jobs=2)]: Done 4950 out of 4950 | elapsed:    3.1s finished

# %%
def make_chunks(chunkable, n):
    """ Yield successive n-sized chunks from l.
    """
    for i in range(0, len(chunkable), n):
        yield (i,i+n)
        
chunks = list(make_chunks(range(0, len(df)), 400))
print(len(chunks))


# def f(pair):
#     return pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)

def process_chunk(n):
    paires = list(itertools.product(df['cdr3'], df['cdr3'][chunks[n][0] : chunks[n][1]]))
    
    fname_out = "{}.txt".format(n)
    with open(fname_out, 'a') as f:
        for pair in paires:
            result = pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)
            for it in range(len(list(result)[0])):
                f.write(str(list(result)[0][it]))
    
    
        
    #     results = Parallel(n_jobs=16, verbose=1, backend="threading")(map(delayed(f), itertools.combinations(cdr3, 2)))
    
    
    
    
process_chunk(0)
# Out:
# 34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-39bba1755d4f> in <module>()
#      29
#      30
# ---> 31 process_chunk(0)
#
# <ipython-input-70-39bba1755d4f> in process_chunk(n)
#      18     with open(fname_out, 'a') as f:
#      19         for pair in paires:
# ---> 20             result = pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)
#      21             for it in range(len(list(result)[0])):
#      22                 f.write(str(list(result)[0][it]))
#
# /usr/local/lib/python3.6/dist-packages/Bio/pairwise2.py in __getattr__(self, attr)
#     416         wrapper_dict['__doc__'] = wrapper.__doc__
#     417         new_alignment_function = type('alignment_function', (object,),
# --> 418                                       wrapper_dict)
#     419
#     420         return new_alignment_function(attr)
#
# KeyboardInterrupt:

# %%
list(itertools.combinations([1, 2, 3], 2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
list(itertools.product([1, 2, 3], [4, 5]))
# Out:
# [(1, 4), (1, 5), (2, 4), (2, 5), (3, 4), (3, 5)]
