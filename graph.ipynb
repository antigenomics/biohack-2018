# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import networkx as nx
from nxpd import nxpdParams, draw
nxpdParams['show'] = 'ipynb'
import operator
# %matplotlib inline

# %%
PATH_TO_FILTERED_VDJDB = "vdjdb.txt"

# %%
df = pd.read_table(PATH_TO_FILTERED_VDJDB)

# %%
df.head()
# Out:
#                 cdr3 antigen.epitope antigen.gene antigen.species      v.segm  \
# 0        CASSFSGTQYF       NLVPMVATV          p65             CMV   TRBV28*01
# 1    CASSLGTSGGNEQFF       NLVPMVATV          p65             CMV  TRBV7-6*01
# 2    CASSQVEEFHGELFF       GILGFVFTL           M1      InfluenzaA  TRBV7-9*01
# 3      CASRTQRWETQYF       QASQEVKNW          p24           HIV-1   TRBV27*01
# 4  CASSPRQGLEGANVLTF       LPPIVAKEI          Int           HIV-1  TRBV7-9*01
#
#        j.segm  v.end  j.start        mhc.a mhc.b mhc.class
# 0  TRBJ2-3*01      4        7     HLA-A*02   B2M      MHCI
# 1  TRBJ2-1*01      5       10     HLA-A*02   B2M      MHCI
# 2  TRBJ2-2*01      4       10     HLA-A*02   B2M      MHCI
# 3  TRBJ2-5*01      3        8     HLA-B*57   B2M      MHCI
# 4  TRBJ2-6*01      4       10  HLA-B*42:01   B2M      MHCI

# %%
unique_eps = df['antigen.epitope'].unique()
print(unique_eps)
# Out:
# ['NLVPMVATV' 'GILGFVFTL' 'QASQEVKNW' 'LPPIVAKEI' 'HPKVSSEVHI' 'TPRVTGGGAM'
#  'GTSGSPIVNR' 'VTEHDTLLY' 'GLCTLVAML' 'LLWNGPMAV' 'YVLDHLIVV' 'KAFSPEVIPMF'
#  'AMFWSVPTV' 'GTSGSPIINR' 'GPGHKARVL' 'IPSINVHHY' 'LLLGIGILV' 'EPLPQGQLTAY'
#  'ELAGIGILTV' 'KRWIILGLNK' 'LPRRSGAAGA' 'FRDYVDRFYKTLRAEQASQE' 'CINGVCWTV'
#  'ISPRTLNAW' 'RAKFKQLL' 'FLKEKGGL' 'RPRGEVRFL' 'PKYVKQNTLKLAT' 'FLYNLLTRV'
#  'NLSALGIFST' 'IVTDFSVIK' 'ATDALMTGY' 'KLVALGINAV' 'TPGPGVRYPL'
#  'KRWIIMGLNK' 'TPQDLNTML' 'FPRPWLHGL' 'GTSGSPIIDK' 'EIYKRWII' 'IIKDYGKQM'
#  'ARMILMTHF' 'QVPLRPMTYK' 'HSKKKCDEL' 'SLYNTVATL']

# %%
# from Bio import pairwise2
# from Bio.pairwise2 import format_alignment
# from Bio.SubsMat import MatrixInfo as matlist
# from math import exp

# D_ep = np.ndarray(shape=(len(unique_eps), len(unique_eps)))
# matrix = matlist.blosum62

# for i in range(len(unique_eps)):
#     for j in range(len(unique_eps)):
#         #print(pairwise2.align.globaldx(unique_eps[i], unique_eps[j], matrix))
#         D_ep[i, j] = pairwise2.align.globaldx(unique_eps[i], unique_eps[j], matrix)[0][2]

# print(np.max(D_ep))
# D_ep = D_ep / np.max(D_ep)  
        
# plt.imshow(D_ep)

# %%
PATH_TO_DIST = "pairwise_distances.txt/data"
dist = pd.read_table(PATH_TO_DIST)    
print(dist.head())

print(len(dist))
# Out:
#        species gene               to            from  indels  substs  \
# 0  HomoSapiens  TRA  CAAAATPGNTGKLIF  CAAFDSGNTGKLIF       1       3
# 1  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAFPGNTDKLIF       2       2
# 2  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAPGENTGKLIF       2       2
# 3  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAPPRNTGKLIF       2       2
# 4  HomoSapiens  TRA  CAAAATPGNTGKLIF   CAAPPSNTGKLIF       2       2
#
#          ag1        ag2
# 0  NLVPMVATV  GILGFVFTL
# 1  GILGFVFTL  GILGFVFTL
# 2  GILGFVFTL  GILGFVFTL
# 3  GILGFVFTL  GILGFVFTL
# 4  GILGFVFTL  GILGFVFTL
# 4594734

# %%
grouped = df.groupby('antigen.epitope')
for it in grouped:
    cdrs = set(it[1]['cdr3'])
    d = dist.loc[(dist['to'].isin(cdrs)) & dist['from'].isin(cdrs)]
    print(Counter(it[1]['antigen.species']))
    print("N paires is pairwise_distances.txt: {}".format(len(d)))

    tmp = ["subs_" + str(row[0]) + "_ind_" + str(row[1]) for index, row in d[['substs', 'indels']].iterrows()]
    print(sorted(dict(Counter(tmp)).items(), key=operator.itemgetter(1), reverse=True))

    print("\n======\n")
# Out:
# Counter({'HomoSapiens': 83})
# N paires is pairwise_distances.txt: 394
# [('subs_3_ind_2', 130), ('subs_3_ind_1', 92), ('subs_2_ind_1', 50), ('subs_3_ind_0', 38), ('subs_2_ind_2', 36), ('subs_1_ind_0', 22), ('subs_1_ind_1', 14), ('subs_2_ind_0', 12)]
#
# ======
#
# Counter({'HCV': 50})
# N paires is pairwise_distances.txt: 158
# [('subs_3_ind_1', 38), ('subs_3_ind_2', 34), ('subs_3_ind_0', 32), ('subs_2_ind_0', 20), ('subs_1_ind_0', 10), ('subs_2_ind_1', 10), ('subs_2_ind_2', 8), ('subs_1_ind_1', 6)]
#
# ======
#
# Counter({'HCV': 165})
# N paires is pairwise_distances.txt: 784
# [('subs_3_ind_0', 364), ('subs_2_ind_0', 204), ('subs_3_ind_1', 94), ('subs_1_ind_0', 60), ('subs_3_ind_2', 28), ('subs_2_ind_1', 20), ('subs_2_ind_2', 8), ('subs_0_ind_2', 2), ('subs_1_ind_2', 2), ('subs_1_ind_1', 2)]
#
# ======
#
# Counter({'HCV': 130})
# N paires is pairwise_distances.txt: 328
# [('subs_3_ind_2', 116), ('subs_3_ind_1', 72), ('subs_3_ind_0', 46), ('subs_2_ind_2', 34), ('subs_2_ind_1', 20), ('subs_2_ind_0', 18), ('subs_1_ind_0', 10), ('subs_1_ind_2', 10), ('subs_1_ind_1', 2)]
#
# ======
#
# Counter({'HIV-1': 38})
# N paires is pairwise_distances.txt: 50
# [('subs_2_ind_0', 18), ('subs_1_ind_0', 16), ('subs_3_ind_0', 6), ('subs_3_ind_1', 4), ('subs_3_ind_2', 2), ('subs_2_ind_1', 2), ('subs_2_ind_2', 2)]
#
# ======
#
# Counter({'HomoSapiens': 973})
# N paires is pairwise_distances.txt: 20598
# [('subs_3_ind_2', 8184), ('subs_3_ind_1', 6038), ('subs_2_ind_2', 2626), ('subs_2_ind_1', 1478), ('subs_3_ind_0', 1276), ('subs_1_ind_2', 452), ('subs_2_ind_0', 250), ('subs_1_ind_1', 196), ('subs_0_ind_2', 48), ('subs_1_ind_0', 34), ('subs_0_ind_1', 16)]
#
# ======
#
# Counter({'EBV': 31})
# N paires is pairwise_distances.txt: 168
# [('subs_2_ind_0', 42), ('subs_1_ind_0', 40), ('subs_3_ind_0', 22), ('subs_3_ind_1', 18), ('subs_2_ind_1', 16), ('subs_1_ind_1', 14), ('subs_0_ind_1', 8), ('subs_3_ind_2', 6), ('subs_0_ind_2', 2)]
#
# ======
#
# Counter({'HIV-1': 73})
# N paires is pairwise_distances.txt: 118
# [('subs_3_ind_2', 28), ('subs_3_ind_1', 26), ('subs_3_ind_0', 18), ('subs_2_ind_0', 14), ('subs_1_ind_0', 10), ('subs_2_ind_2', 10), ('subs_2_ind_1', 8), ('subs_1_ind_2', 4)]
#
# ======
#
# Counter({'HomoSapiens': 61})
# N paires is pairwise_distances.txt: 300
# [('subs_3_ind_2', 102), ('subs_2_ind_2', 44), ('subs_3_ind_1', 38), ('subs_3_ind_0', 34), ('subs_2_ind_0', 28), ('subs_2_ind_1', 22), ('subs_1_ind_0', 18), ('subs_1_ind_1', 12), ('subs_1_ind_2', 2)]
#
# ======
#
# Counter({'HIV-1': 88})
# N paires is pairwise_distances.txt: 618
# [('subs_3_ind_0', 192), ('subs_2_ind_0', 188), ('subs_1_ind_0', 86), ('subs_3_ind_1', 60), ('subs_3_ind_2', 46), ('subs_2_ind_1', 30), ('subs_1_ind_1', 8), ('subs_2_ind_2', 8)]
#
# ======
#
# Counter({'HIV-1': 387})
# N paires is pairwise_distances.txt: 10540
# [('subs_3_ind_1', 3096), ('subs_3_ind_0', 2678), ('subs_2_ind_0', 1510), ('subs_2_ind_1', 1176), ('subs_3_ind_2', 934), ('subs_1_ind_0', 446), ('subs_2_ind_2', 360), ('subs_1_ind_1', 276), ('subs_1_ind_2', 36), ('subs_0_ind_1', 18), ('subs_0_ind_2', 10)]
#
# ======
#
# Counter({'InfluenzaA': 2638})
# N paires is pairwise_distances.txt: 253650
# [('subs_3_ind_2', 77242), ('subs_3_ind_1', 54822), ('subs_3_ind_0', 53098), ('subs_2_ind_2', 24256), ('subs_2_ind_0', 19538), ('subs_2_ind_1', 14686), ('subs_1_ind_2', 4062), ('subs_1_ind_0', 3728), ('subs_1_ind_1', 1888), ('subs_0_ind_2', 252), ('subs_0_ind_1', 78)]
#
# ======
#
# Counter({'EBV': 857})
# N paires is pairwise_distances.txt: 17878
# [('subs_3_ind_2', 5820), ('subs_3_ind_1', 4312), ('subs_2_ind_2', 1922), ('subs_3_ind_0', 1820), ('subs_2_ind_1', 1406), ('subs_2_ind_0', 1228), ('subs_1_ind_0', 588), ('subs_1_ind_2', 402), ('subs_1_ind_1', 296), ('subs_0_ind_1', 44), ('subs_0_ind_2', 40)]
#
# ======
#
# Counter({'HIV-1': 72})
# N paires is pairwise_distances.txt: 108
# [('subs_3_ind_2', 38), ('subs_3_ind_1', 26), ('subs_1_ind_0', 18), ('subs_2_ind_0', 10), ('subs_2_ind_2', 6), ('subs_3_ind_0', 4), ('subs_2_ind_1', 4), ('subs_1_ind_1', 2)]
#
# ======
#
# Counter({'DENV2': 60})
# N paires is pairwise_distances.txt: 696
# [('subs_3_ind_2', 244), ('subs_3_ind_1', 150), ('subs_1_ind_0', 126), ('subs_2_ind_0', 88), ('subs_2_ind_2', 38), ('subs_2_ind_1', 26), ('subs_3_ind_0', 20), ('subs_1_ind_2', 4)]
#
# ======
#
# Counter({'DENV3/4': 160})
# N paires is pairwise_distances.txt: 6730
# [('subs_3_ind_1', 1874), ('subs_3_ind_2', 1738), ('subs_3_ind_0', 808), ('subs_2_ind_2', 588), ('subs_2_ind_1', 584), ('subs_2_ind_0', 530), ('subs_1_ind_0', 286), ('subs_1_ind_2', 182), ('subs_1_ind_1', 110), ('subs_0_ind_1', 22), ('subs_0_ind_2', 8)]
#
# ======
#
# Counter({'DENV1': 168})
# N paires is pairwise_distances.txt: 6296
# [('subs_3_ind_2', 1778), ('subs_3_ind_1', 1328), ('subs_3_ind_0', 844), ('subs_2_ind_2', 772), ('subs_2_ind_0', 520), ('subs_2_ind_1', 500), ('subs_1_ind_2', 240), ('subs_1_ind_0', 204), ('subs_1_ind_1', 90), ('subs_0_ind_2', 12), ('subs_0_ind_1', 8)]
#
# ======
#
# Counter({'HIV-1': 54})
# N paires is pairwise_distances.txt: 164
# [('subs_3_ind_0', 64), ('subs_2_ind_0', 38), ('subs_1_ind_0', 34), ('subs_3_ind_1', 16), ('subs_3_ind_2', 12)]
#
# ======
#
# Counter({'HCV': 31})
# N paires is pairwise_distances.txt: 30
# [('subs_1_ind_0', 18), ('subs_2_ind_2', 4), ('subs_3_ind_2', 2), ('subs_3_ind_1', 2), ('subs_2_ind_1', 2), ('subs_3_ind_0', 2)]
#
# ======
#
# Counter({'HIV-1': 37})
# N paires is pairwise_distances.txt: 124
# [('subs_3_ind_0', 48), ('subs_1_ind_0', 34), ('subs_2_ind_0', 32), ('subs_2_ind_2', 4), ('subs_3_ind_1', 4), ('subs_3_ind_2', 2)]
#
# ======
#
# Counter({'CMV': 55})
# N paires is pairwise_distances.txt: 190
# [('subs_3_ind_1', 36), ('subs_3_ind_2', 34), ('subs_3_ind_0', 32), ('subs_2_ind_0', 30), ('subs_2_ind_2', 22), ('subs_1_ind_0', 18), ('subs_2_ind_1', 10), ('subs_1_ind_2', 4), ('subs_1_ind_1', 2), ('subs_0_ind_1', 2)]
#
# ======
#
# Counter({'HIV-1': 56})
# N paires is pairwise_distances.txt: 92
# [('subs_3_ind_0', 26), ('subs_3_ind_1', 20), ('subs_1_ind_0', 18), ('subs_2_ind_0', 16), ('subs_3_ind_2', 8), ('subs_2_ind_2', 4)]
#
# ======
#
# Counter({'EBV': 32})
# N paires is pairwise_distances.txt: 58
# [('subs_3_ind_0', 20), ('subs_1_ind_0', 14), ('subs_2_ind_0', 14), ('subs_2_ind_1', 10)]
#
# ======
#
# Counter({'HIV-1': 181})
# N paires is pairwise_distances.txt: 4846
# [('subs_3_ind_1', 1120), ('subs_3_ind_0', 944), ('subs_2_ind_1', 784), ('subs_2_ind_0', 520), ('subs_3_ind_2', 486), ('subs_2_ind_2', 372), ('subs_1_ind_1', 232), ('subs_1_ind_0', 230), ('subs_1_ind_2', 120), ('subs_0_ind_1', 30), ('subs_0_ind_2', 8)]
#
# ======
#
# Counter({'HCV': 66})
# N paires is pairwise_distances.txt: 336
# [('subs_3_ind_2', 86), ('subs_3_ind_1', 82), ('subs_2_ind_2', 50), ('subs_2_ind_1', 42), ('subs_3_ind_0', 28), ('subs_1_ind_2', 16), ('subs_1_ind_1', 12), ('subs_2_ind_0', 10), ('subs_1_ind_0', 6), ('subs_0_ind_1', 2), ('subs_0_ind_2', 2)]
#
# ======
#
# Counter({'HIV-1': 285})
# N paires is pairwise_distances.txt: 4010
# [('subs_3_ind_2', 1124), ('subs_3_ind_1', 730), ('subs_2_ind_0', 498), ('subs_3_ind_0', 476), ('subs_2_ind_1', 424), ('subs_2_ind_2', 336), ('subs_1_ind_0', 260), ('subs_1_ind_1', 82), ('subs_1_ind_2', 56), ('subs_0_ind_1', 24)]
#
# ======
#
# Counter({'HIV-1': 71})
# N paires is pairwise_distances.txt: 356
# [('subs_3_ind_0', 84), ('subs_1_ind_0', 80), ('subs_2_ind_0', 74), ('subs_3_ind_2', 34), ('subs_3_ind_1', 32), ('subs_2_ind_2', 22), ('subs_2_ind_1', 18), ('subs_1_ind_1', 6), ('subs_0_ind_1', 6)]
#
# ======
#
# Counter({'HomoSapiens': 232})
# N paires is pairwise_distances.txt: 1778
# [('subs_3_ind_1', 446), ('subs_3_ind_2', 414), ('subs_2_ind_1', 284), ('subs_3_ind_0', 218), ('subs_2_ind_2', 186), ('subs_2_ind_0', 114), ('subs_1_ind_1', 54), ('subs_1_ind_2', 34), ('subs_1_ind_0', 26), ('subs_0_ind_2', 2)]
#
# ======
#
# Counter({'YellowFeverVirus': 286})
# N paires is pairwise_distances.txt: 5238
# [('subs_3_ind_1', 1580), ('subs_3_ind_2', 1084), ('subs_2_ind_1', 694), ('subs_3_ind_0', 648), ('subs_2_ind_2', 508), ('subs_2_ind_0', 254), ('subs_1_ind_1', 186), ('subs_1_ind_2', 174), ('subs_1_ind_0', 82), ('subs_0_ind_2', 16), ('subs_0_ind_1', 12)]
#
# ======
#
# Counter({'HIV-1': 43})
# N paires is pairwise_distances.txt: 156
# [('subs_3_ind_0', 54), ('subs_2_ind_0', 44), ('subs_1_ind_0', 28), ('subs_3_ind_2', 12), ('subs_2_ind_1', 10), ('subs_3_ind_1', 6), ('subs_1_ind_1', 2)]
#
# ======
#
# Counter({'InfluenzaA': 159})
# N paires is pairwise_distances.txt: 566
# [('subs_3_ind_2', 232), ('subs_3_ind_1', 164), ('subs_2_ind_2', 78), ('subs_2_ind_1', 50), ('subs_3_ind_0', 20), ('subs_1_ind_2', 10), ('subs_1_ind_1', 8), ('subs_1_ind_0', 2), ('subs_0_ind_2', 2)]
# ======
#
# Counter({'HomoSapiens': 112})
# N paires is pairwise_distances.txt: 506
# [('subs_3_ind_2', 196), ('subs_3_ind_1', 118), ('subs_2_ind_2', 86), ('subs_2_ind_1', 32), ('subs_3_ind_0', 24), ('subs_1_ind_2', 22), ('subs_2_ind_0', 10), ('subs_1_ind_1', 6), ('subs_1_ind_0', 6), ('subs_0_ind_1', 4), ('subs_0_ind_2', 2)]
#
# ======
#
# Counter({'CMV': 4405})
# N paires is pairwise_distances.txt: 372290
# [('subs_3_ind_2', 155894), ('subs_3_ind_1', 99392), ('subs_2_ind_2', 49100), ('subs_2_ind_1', 25562), ('subs_3_ind_0', 21162), ('subs_1_ind_2', 9136), ('subs_2_ind_0', 6174), ('subs_1_ind_1', 3800), ('subs_1_ind_0', 1238), ('subs_0_ind_2', 614), ('subs_0_ind_1', 218)]
#
# ======
#
# Counter({'InfluenzaA': 294})
# N paires is pairwise_distances.txt: 1736
# [('subs_3_ind_2', 752), ('subs_3_ind_1', 426), ('subs_2_ind_2', 238), ('subs_2_ind_1', 128), ('subs_3_ind_0', 106), ('subs_1_ind_2', 28), ('subs_2_ind_0', 26), ('subs_1_ind_0', 16), ('subs_1_ind_1', 12), ('subs_0_ind_2', 4)]
#
# ======
#
# Counter({'HIV-1': 30})
# N paires is pairwise_distances.txt: 26
# [('subs_2_ind_0', 8), ('subs_1_ind_0', 6), ('subs_3_ind_1', 6), ('subs_2_ind_2', 4), ('subs_3_ind_2', 2)]
#
# ======
#
# Counter({'HIV-1': 48})
# N paires is pairwise_distances.txt: 40
# [('subs_1_ind_0', 14), ('subs_2_ind_2', 10), ('subs_3_ind_1', 6), ('subs_2_ind_0', 4), ('subs_3_ind_2', 4), ('subs_2_ind_1', 2)]
#
# ======
#
# Counter({'EBV': 179})
# N paires is pairwise_distances.txt: 804
# [('subs_3_ind_2', 246), ('subs_3_ind_1', 174), ('subs_2_ind_1', 76), ('subs_3_ind_0', 74), ('subs_1_ind_0', 64), ('subs_2_ind_2', 64), ('subs_2_ind_0', 60), ('subs_1_ind_1', 22), ('subs_1_ind_2', 18), ('subs_0_ind_1', 6)]
#
# ======
#
# Counter({'HSV-2': 32})
# N paires is pairwise_distances.txt: 46
# [('subs_1_ind_0', 12), ('subs_3_ind_1', 10), ('subs_3_ind_2', 8), ('subs_2_ind_0', 6), ('subs_2_ind_1', 4), ('subs_0_ind_1', 2), ('subs_3_ind_0', 2), ('subs_2_ind_2', 2)]
#
# ======
#
# Counter({'HIV-1': 37})
# N paires is pairwise_distances.txt: 136
# [('subs_2_ind_0', 50), ('subs_1_ind_0', 36), ('subs_3_ind_0', 32), ('subs_3_ind_2', 12), ('subs_3_ind_1', 4), ('subs_2_ind_2', 2)]
#
# ======
#
# Counter({'HIV-1': 45})
# N paires is pairwise_distances.txt: 86
# [('subs_3_ind_2', 28), ('subs_3_ind_0', 26), ('subs_3_ind_1', 14), ('subs_1_ind_0', 12), ('subs_2_ind_2', 4), ('subs_2_ind_0', 2)]
#
# ======
#
# Counter({'HIV-1': 103})
# N paires is pairwise_distances.txt: 708
# [('subs_3_ind_1', 184), ('subs_3_ind_2', 120), ('subs_2_ind_1', 102), ('subs_3_ind_0', 84), ('subs_2_ind_2', 58), ('subs_1_ind_0', 54), ('subs_2_ind_0', 50), ('subs_1_ind_1', 30), ('subs_1_ind_2', 16), ('subs_0_ind_1', 10)]
#
# ======
#
# Counter({'CMV': 131})
# N paires is pairwise_distances.txt: 418
# [('subs_3_ind_0', 112), ('subs_2_ind_0', 68), ('subs_1_ind_0', 68), ('subs_3_ind_2', 66), ('subs_3_ind_1', 60), ('subs_2_ind_2', 24), ('subs_1_ind_2', 10), ('subs_2_ind_1', 8), ('subs_0_ind_1', 2)]
#
# ======
#
# Counter({'CMV': 201})
# N paires is pairwise_distances.txt: 1296
# [('subs_3_ind_2', 518), ('subs_3_ind_1', 354), ('subs_2_ind_2', 162), ('subs_2_ind_1', 114), ('subs_3_ind_0', 80), ('subs_1_ind_2', 24), ('subs_1_ind_1', 16), ('subs_1_ind_0', 10), ('subs_0_ind_2', 10), ('subs_2_ind_0', 8)]
#
# ======
#
# Counter({'EBV': 81})
# N paires is pairwise_distances.txt: 108
# [('subs_3_ind_2', 38), ('subs_3_ind_1', 22), ('subs_3_ind_0', 20), ('subs_2_ind_1', 14), ('subs_2_ind_2', 6), ('subs_2_ind_0', 4), ('subs_1_ind_1', 2), ('subs_1_ind_0', 2)]
#
# ======

# %%
for it in grouped:
    if list(dict(Counter(list(it[1]['antigen.species']))).keys())[0] == 'InfluenzaA':
        cdrs = set(it[1]['cdr3'])
        d = dist.loc[(dist['to'].isin(cdrs)) & dist['from'].isin(cdrs)]

        d_unique = d['to'].unique()
        M = np.zeros((len(d_unique), len(d_unique)))
        M_labels = {}
        for i in range(len(d_unique)):
            M_labels[d_unique[i]] = i

        for index, row in d[['substs', 'indels']].iterrows():
            if row[0] <= 3 & row[1] <= 1:
                M[M_labels[d['to'][index]], M_labels[d['from'][index]]] = 1
                M[M_labels[d['from'][index]], M_labels[d['to'][index]]] = 1

        break

# %%
#plot graph

G = nx.DiGraph()
G.graph['rankdir'] = 'LR'
G.graph['dpi'] = 120
for i in range(len(M)):
    G.add_node(i)

for i in range(len(M)):
    for j in range(len(M)):
        if (M[i, j] > 0):
            G.add_edge(i, j)

draw(G)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.185759 to fit

# %%
# треш

# %%
mult = [(k, v) for k, v in dict(Counter(df['cdr3'])).items() if v > 1]
print(mult)

# %%
len(Counter(df['cdr3']))

# %%
len(Counter(df['antigen.epitope']))

# %%
# 1) gap penalty = -(max(vdjam) + 1)
# 2) score1 = global alignment score - gap penalty * #indels
# 3) score2(i,j) = score1(i, j) - max (score1(i,i), score2(j,j)) где i и j это два CDR3

# %%
PATH_TO_VDJAM = "./alignment_matrix/vdjam.txt"

# %%
m = pd.read_table(PATH_TO_VDJAM)
m.head()

# %%
vdjam = {}

for index, row in m.iterrows():
    vdjam[(row['aa.1'], row['aa.2'])] = row['score']
    
gap_penalty = -(max(vdjam.values()) + 1)

print(gap_penalty)

# %%
from Bio import pairwise2
from Bio.pairwise2 import format_alignment


for a in pairwise2.align.globalds("KEVLA", "EVL", vdjam, gap_penalty, gap_penalty):
    print(format_alignment(*a))

# %%
import itertools
from joblib import Parallel, delayed

cdr3 = df.head(100)['cdr3']

def f(pair):
    return pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)

results = Parallel(n_jobs=2, verbose=1, backend="threading")(map(delayed(f), itertools.combinations(cdr3, 2)))
print(results)

# %%
def make_chunks(chunkable, n):
    """ Yield successive n-sized chunks from l.
    """
    for i in range(0, len(chunkable), n):
        yield (i,i+n)
        
chunks = list(make_chunks(range(0, len(df)), 400))
print(len(chunks))


# def f(pair):
#     return pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)

def process_chunk(n):
    paires = list(itertools.product(df['cdr3'], df['cdr3'][chunks[n][0] : chunks[n][1]]))
    
    fname_out = "{}.txt".format(n)
    with open(fname_out, 'a') as f:
        for pair in paires:
            result = pairwise2.align.globalds(pair[0], pair[1], vdjam, gap_penalty - 1, gap_penalty)
            for it in range(len(list(result)[0])):
                f.write(str(list(result)[0][it]))
    
    
        
    #     results = Parallel(n_jobs=16, verbose=1, backend="threading")(map(delayed(f), itertools.combinations(cdr3, 2)))
    
    
    
    
process_chunk(0)

# %%
list(itertools.combinations([1, 2, 3], 2))

# %%
list(itertools.product([1, 2, 3], [4, 5]))
